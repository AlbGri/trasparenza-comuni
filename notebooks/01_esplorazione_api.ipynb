# %%
"""
Visualizzazione dati comunali
"""
import json
import pandas as pd
import matplotlib.pyplot as plt

def load_test_data():
    """Carica i dati di test salvati"""
    with open("../src/data/raw/bilanci_test.json", "r", encoding='utf-8') as f:
        bilanci = json.load(f)
    return bilanci

def crea_grafico_confronto():
    """Crea un grafico di confronto tra comuni"""
    bilanci = load_test_data()
    
    # Prepara i dati per il grafico
    comuni = list(bilanci.keys())
    spese_procapite = [b['spesa_procapite'] for b in bilanci.values()]
    popolazione = [b['popolazione'] for b in bilanci.values()]
    
    # Crea il grafico
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
    
    # Grafico 1: Spesa pro-capite
    ax1.bar(comuni, spese_procapite, color=['#1f77b4', '#ff7f0e', '#2ca02c'])
    ax1.set_title('Spesa Pro-Capite per Comune')
    ax1.set_ylabel('Euro per abitante')
    ax1.set_xlabel('Comune')
    
    # Grafico 2: Popolazione
    ax2.bar(comuni, popolazione, color=['#d62728', '#9467bd', '#8c564b'])
    ax2.set_title('Popolazione per Comune')
    ax2.set_ylabel('Abitanti')
    ax2.set_xlabel('Comune')
    
    plt.tight_layout()
    
    # Salva il grafico
    plt.savefig('../src/data/processed/confronto_comuni.png')
    print("📊 Grafico salvato in data/processed/confronto_comuni.png")
    plt.show()

if __name__ == "__main__":
    print("📊 Generazione grafici...")
    crea_grafico_confronto()
# Out:
# 📊 Generazione grafici...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 47
#      45 if __name__ == "__main__":
#      46     print("📊 Generazione grafici...")
# ---> 47     crea_grafico_confronto()
#
# Cell In[9], line 41, in crea_grafico_confronto()
#      38 plt.tight_layout()
#      40 # Salva il grafico
# ---> 41 plt.savefig('../src/data/processed/confronto_comuni.png')
#      42 print("📊 Grafico salvato in data/processed/confronto_comuni.png")
#      43 plt.show()
#
# File ~\.conda\envs\trasparenza\Lib\site-packages\matplotlib\pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
# ...
